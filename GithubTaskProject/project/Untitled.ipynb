# %%
from github import Github

# First create a Github instance:

# using username and password
g = Github("user", "password")

# %%
from github import Github

g = Github("user","password")

g = Github(base_url="https://{hostname}/api/v3", login_or_token="access_token")

for repo in g.get_user().get_repos():
    print(repo.name)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-c42cc657bd1e> in <module>()
#       5 g = Github(base_url="https://{hostname}/api/v3", login_or_token="access_token")
#       6
# ----> 7 for repo in g.get_user().get_repos():
#       8     print(repo.name)
#
# /home/sss/.local/lib/python2.7/site-packages/github/PaginatedList.pyc in __iter__(self)
#      56             yield element
#      57         while self._couldGrow():
# ---> 58             newElements = self._grow()
#      59             for element in newElements:
#      60                 yield element
#
# /home/sss/.local/lib/python2.7/site-packages/github/PaginatedList.pyc in _grow(self)
#      68
#      69     def _grow(self):
# ---> 70         newElements = self._fetchNextPage()
#      71         self.__elements += newElements
#      72         return newElements
#
# /home/sss/.local/lib/python2.7/site-packages/github/PaginatedList.pyc in _fetchNextPage(self)
#     170             self.__nextUrl,
#     171             parameters=self.__nextParams,
# --> 172             headers=self.__headers
#     173         )
#     174         data = data if data else []
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     258
#     259     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
# --> 260         return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#     261
#     262     def requestMultipartAndCheck(self, verb, url, parameters=None, headers=None, input=None):
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in requestJson(self, verb, url, parameters, headers, input, cnx)
#     315             return "application/json", json.dumps(input)
#     316
# --> 317         return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#     318
#     319     def requestMultipart(self, verb, url, parameters=None, headers=None, input=None, cnx=None):
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in __requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     368         self.NEW_DEBUG_FRAME(requestHeaders)
#     369
# --> 370         status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     371
#     372         if "x-ratelimit-remaining" in responseHeaders and "x-ratelimit-limit" in responseHeaders:
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in __requestRaw(self, cnx, verb, url, requestHeaders, input)
#     392             requestHeaders
#     393         )
# --> 394         response = cnx.getresponse()
#     395
#     396         status = response.status
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in getresponse(self)
#     105         verb = getattr(self.session, self.verb.lower())
#     106         url = "%s://%s:%s%s" % (self.protocol, self.host, self.port, self.url)
# --> 107         r = verb(url, headers=self.headers, data=self.input, timeout=self.timeout, verify=self.verify)
#     108         return RequestsResponse(r)
#     109
#
# /home/sss/.local/lib/python2.7/site-packages/requests/sessions.pyc in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# /home/sss/.local/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /home/sss/.local/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /home/sss/.local/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='%7bhostname%7d', port=443): Max retries exceeded with url: /api/v3/user/repos (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe8ba248410>: Failed to establish a new connection: [Errno -2] Name or service not known',))

# %%
for repo in g.get_user().get_repos():
    print(repo.name)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-6-1c7b2c0f846f> in <module>()
# ----> 1 for repo in g.get_user().get_repos():
#       2     print(repo.name)
#
# /home/sss/.local/lib/python2.7/site-packages/github/PaginatedList.pyc in __iter__(self)
#      56             yield element
#      57         while self._couldGrow():
# ---> 58             newElements = self._grow()
#      59             for element in newElements:
#      60                 yield element
#
# /home/sss/.local/lib/python2.7/site-packages/github/PaginatedList.pyc in _grow(self)
#      68
#      69     def _grow(self):
# ---> 70         newElements = self._fetchNextPage()
#      71         self.__elements += newElements
#      72         return newElements
#
# /home/sss/.local/lib/python2.7/site-packages/github/PaginatedList.pyc in _fetchNextPage(self)
#     170             self.__nextUrl,
#     171             parameters=self.__nextParams,
# --> 172             headers=self.__headers
#     173         )
#     174         data = data if data else []
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     258
#     259     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
# --> 260         return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#     261
#     262     def requestMultipartAndCheck(self, verb, url, parameters=None, headers=None, input=None):
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in requestJson(self, verb, url, parameters, headers, input, cnx)
#     315             return "application/json", json.dumps(input)
#     316
# --> 317         return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#     318
#     319     def requestMultipart(self, verb, url, parameters=None, headers=None, input=None, cnx=None):
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in __requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     368         self.NEW_DEBUG_FRAME(requestHeaders)
#     369
# --> 370         status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     371
#     372         if "x-ratelimit-remaining" in responseHeaders and "x-ratelimit-limit" in responseHeaders:
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in __requestRaw(self, cnx, verb, url, requestHeaders, input)
#     392             requestHeaders
#     393         )
# --> 394         response = cnx.getresponse()
#     395
#     396         status = response.status
#
# /home/sss/.local/lib/python2.7/site-packages/github/Requester.pyc in getresponse(self)
#     105         verb = getattr(self.session, self.verb.lower())
#     106         url = "%s://%s:%s%s" % (self.protocol, self.host, self.port, self.url)
# --> 107         r = verb(url, headers=self.headers, data=self.input, timeout=self.timeout, verify=self.verify)
#     108         return RequestsResponse(r)
#     109
#
# /home/sss/.local/lib/python2.7/site-packages/requests/sessions.pyc in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# /home/sss/.local/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /home/sss/.local/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /home/sss/.local/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='%7bhostname%7d', port=443): Max retries exceeded with url: /api/v3/user/repos (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fe8bac35050>: Failed to establish a new connection: [Errno -2] Name or service not known',))
